# %% [markdown]
# # Getting started

# %% [markdown]
# In this notebook, we show how to use seqme to evaluate biological sequences and add your own metric. We introduce seqme's functionality through toy examples. Other tutorials show real-world use cases.

# %% [markdown]
# First the imports.

# %%
from pprint import pprint
from typing import Literal

import numpy as np

import seqme as sm

# %% [markdown]
# ## Basics

# %% [markdown]
# Let's define the sequences to use and the metrics to compute. Some sequences will be loaded from fasta files, others are hard-coded.

# %% [markdown]
# First let's write a fasta file with random sequences to disk.

# %%
RANDOM_SEQUENCES_PATH = "./data/random.fasta"

# %%
random_sequences = ["KKKKK", "PLQ", "RKSPL"]

sm.to_fasta(random_sequences, RANDOM_SEQUENCES_PATH)

# %% [markdown]
# UniProt contains a lot of sequences. To speed-up the metric computations, we will only use a (random) subset of the UniProt sequences.

# %%
sequences = {
    "Random": sm.read_fasta(RANDOM_SEQUENCES_PATH),
    "UniProt": sm.utils.subsample(["KKWQ", "RKSPL", "RASD"], n_samples=2, seed=42),
    "HydrAMP": ["MMRK", "RKSPL", "RRLSK", "RRLSK"],
    "hyformer": ["MKQW", "RKSPL"],
}

# %% [markdown]
# Metrics may precompute some values upon metric object creation to speed up the overall process.

# %%
def hit_rate_condition_fn(sequences: list[str]) -> np.ndarray:
    no_lysine = ~np.array(["K" in seq for seq in sequences])
    return no_lysine


def my_embedder(sequences: list[str]) -> np.ndarray:
    lengths = [len(sequence) for sequence in sequences]
    counts = [sequence.count("K") for sequence in sequences]
    return np.array([lengths, counts], dtype=float).T


metrics = [
    sm.metrics.Uniqueness(),
    sm.metrics.Novelty(reference=sequences["UniProt"], name="Novelty (UniProt)"),
    sm.metrics.Diversity(),
    sm.metrics.FBD(reference=sequences["Random"], embedder=my_embedder),
    sm.metrics.ID(sm.models.Gravy(), name="Gravy", objective="minimize"),
    sm.metrics.HitRate(condition_fn=hit_rate_condition_fn),
]

# %% [markdown]
# Let's compute the metrics.

# %%
df = sm.evaluate(sequences, metrics)
# Out:
#  38%|███▊      | 9/24 [00:00<00:00, 31.59it/s, data=UniProt, metric=FBD]              /Users/rasmus.larsen/work/hackathon-2025/seqme/src/seqme/metrics/fbd.py:92: LinAlgWarning: Matrix is singular. The result might be inaccurate or the array might not have a square root.
#   covmean, err = scipy.linalg.sqrtm(sigma1.dot(sigma2), disp=False)
# 100%|██████████| 24/24 [00:00<00:00, 65.49it/s, data=hyformer, metric=Hit-rate]

# %% [markdown]
# Let's look at the results.

# %%
df
# Out:
#          Uniqueness           Novelty (UniProt)           Diversity            \
#               value deviation             value deviation     value deviation
# Random         1.00       NaN               1.0       NaN  0.866667       NaN
# UniProt        1.00       NaN               0.0       NaN  1.000000       NaN
# HydrAMP        0.75       NaN               1.0       NaN  0.700000       NaN
# hyformer       1.00       NaN               1.0       NaN  0.800000       NaN
#
#                FBD               Gravy            Hit-rate
#              value deviation     value deviation     value deviation
# Random    0.000000       NaN -1.911111  1.460678  0.333333       NaN
# UniProt   3.961130       NaN -2.400000  0.650000  0.500000       NaN
# HydrAMP   8.602244       NaN -1.627500  0.363413  0.000000       NaN
# hyformer  8.228118       NaN -1.500000  0.100000  0.000000       NaN

# %% [markdown]
# ... let's make it nicer to look at.

# %%
sm.show(df, n_decimals=3)
# Out:
# <style type="text/css">
# #T_d9e1a th.col_heading {
#   text-align: center;
# }
# #T_d9e1a td {
#   border-right: 1px solid #ccc;
# }
# #T_d9e1a th.row_heading {
#   border-right: 1px solid #ccc;
# }
# #T_d9e1a_row0_col0, #T_d9e1a_row0_col1, #T_d9e1a_row0_col3, #T_d9e1a_row1_col0, #T_d9e1a_row1_col2, #T_d9e1a_row1_col4, #T_d9e1a_row1_col5, #T_d9e1a_row2_col1, #T_d9e1a_row3_col0, #T_d9e1a_row3_col1 {
#   background-color: #68d6bc;
#   font-weight: bold;
# }
# #T_d9e1a_row0_col2, #T_d9e1a_row0_col4, #T_d9e1a_row0_col5, #T_d9e1a_row1_col3 {
#   text-decoration: underline;
# }
# </style>
# <table id="T_d9e1a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9e1a_level0_col0" class="col_heading level0 col0" >Uniqueness↑</th>
#       <th id="T_d9e1a_level0_col1" class="col_heading level0 col1" >Novelty (UniProt)↑</th>
#       <th id="T_d9e1a_level0_col2" class="col_heading level0 col2" >Diversity↑</th>
#       <th id="T_d9e1a_level0_col3" class="col_heading level0 col3" >FBD↓</th>
#       <th id="T_d9e1a_level0_col4" class="col_heading level0 col4" >Gravy↓</th>
#       <th id="T_d9e1a_level0_col5" class="col_heading level0 col5" >Hit-rate↑</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9e1a_level0_row0" class="row_heading level0 row0" >Random</th>
#       <td id="T_d9e1a_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_d9e1a_row0_col1" class="data row0 col1" >1.000</td>
#       <td id="T_d9e1a_row0_col2" class="data row0 col2" >0.867</td>
#       <td id="T_d9e1a_row0_col3" class="data row0 col3" >0.000</td>
#       <td id="T_d9e1a_row0_col4" class="data row0 col4" >-1.911±1.461</td>
#       <td id="T_d9e1a_row0_col5" class="data row0 col5" >0.333</td>
#     </tr>
#     <tr>
#       <th id="T_d9e1a_level0_row1" class="row_heading level0 row1" >UniProt</th>
#       <td id="T_d9e1a_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_d9e1a_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_d9e1a_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_d9e1a_row1_col3" class="data row1 col3" >3.961</td>
#       <td id="T_d9e1a_row1_col4" class="data row1 col4" >-2.400±0.650</td>
#       <td id="T_d9e1a_row1_col5" class="data row1 col5" >0.500</td>
#     </tr>
#     <tr>
#       <th id="T_d9e1a_level0_row2" class="row_heading level0 row2" >HydrAMP</th>
#       <td id="T_d9e1a_row2_col0" class="data row2 col0" >0.750</td>
#       <td id="T_d9e1a_row2_col1" class="data row2 col1" >1.000</td>
#       <td id="T_d9e1a_row2_col2" class="data row2 col2" >0.700</td>
#       <td id="T_d9e1a_row2_col3" class="data row2 col3" >8.602</td>
#       <td id="T_d9e1a_row2_col4" class="data row2 col4" >-1.628±0.363</td>
#       <td id="T_d9e1a_row2_col5" class="data row2 col5" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_d9e1a_level0_row3" class="row_heading level0 row3" >hyformer</th>
#       <td id="T_d9e1a_row3_col0" class="data row3 col0" >1.000</td>
#       <td id="T_d9e1a_row3_col1" class="data row3 col1" >1.000</td>
#       <td id="T_d9e1a_row3_col2" class="data row3 col2" >0.800</td>
#       <td id="T_d9e1a_row3_col3" class="data row3 col3" >8.228</td>
#       <td id="T_d9e1a_row3_col4" class="data row3 col4" >-1.500±0.100</td>
#       <td id="T_d9e1a_row3_col5" class="data row3 col5" >0.000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's also do a parallel coordinates plot.

# %%
sm.plot_parallel(df, arrow_size=12, xticks_fontsize=10, xticks_rotation=35, figsize=(6, 2.5), show_arrow=False)

# %% [markdown]
# We are particularly interested in the following two metrics.

# %%
sm.plot_scatter(df, metrics=["FBD", "Gravy"], show_deviation=False)

# %% [markdown]
# Let's zoom in on one of the metrics.

# %%
sm.plot_bar(df, "Gravy")

# %% [markdown]
# Let's extract the two rows with lowest Gravy.

# %%
sm.show(sm.top_k(df, "Gravy", k=2))
# Out:
# <style type="text/css">
# #T_15d88 th.col_heading {
#   text-align: center;
# }
# #T_15d88 td {
#   border-right: 1px solid #ccc;
# }
# #T_15d88 th.row_heading {
#   border-right: 1px solid #ccc;
# }
# #T_15d88_row0_col0, #T_15d88_row0_col1, #T_15d88_row0_col3, #T_15d88_row1_col0, #T_15d88_row1_col2, #T_15d88_row1_col4, #T_15d88_row1_col5 {
#   background-color: #68d6bc;
#   font-weight: bold;
# }
# #T_15d88_row0_col2, #T_15d88_row0_col4, #T_15d88_row0_col5, #T_15d88_row1_col1, #T_15d88_row1_col3 {
#   text-decoration: underline;
# }
# </style>
# <table id="T_15d88">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15d88_level0_col0" class="col_heading level0 col0" >Uniqueness↑</th>
#       <th id="T_15d88_level0_col1" class="col_heading level0 col1" >Novelty (UniProt)↑</th>
#       <th id="T_15d88_level0_col2" class="col_heading level0 col2" >Diversity↑</th>
#       <th id="T_15d88_level0_col3" class="col_heading level0 col3" >FBD↓</th>
#       <th id="T_15d88_level0_col4" class="col_heading level0 col4" >Gravy↓</th>
#       <th id="T_15d88_level0_col5" class="col_heading level0 col5" >Hit-rate↑</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15d88_level0_row0" class="row_heading level0 row0" >Random</th>
#       <td id="T_15d88_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_15d88_row0_col1" class="data row0 col1" >1.00</td>
#       <td id="T_15d88_row0_col2" class="data row0 col2" >0.87</td>
#       <td id="T_15d88_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_15d88_row0_col4" class="data row0 col4" >-1.91±1.46</td>
#       <td id="T_15d88_row0_col5" class="data row0 col5" >0.33</td>
#     </tr>
#     <tr>
#       <th id="T_15d88_level0_row1" class="row_heading level0 row1" >UniProt</th>
#       <td id="T_15d88_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_15d88_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_15d88_row1_col2" class="data row1 col2" >1.00</td>
#       <td id="T_15d88_row1_col3" class="data row1 col3" >3.96</td>
#       <td id="T_15d88_row1_col4" class="data row1 col4" >-2.40±0.65</td>
#       <td id="T_15d88_row1_col5" class="data row1 col5" >0.50</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's perform a (non-dominated) ranking of the entries, which corresponds to computing slices of the Pareto front from the selected metrics, followed by removing the entries in the current slice. Each slice corresponds to a rank.

# %%
df = sm.rank(df, metrics=["Hit-rate", "Diversity", "Gravy"])

# %% [markdown]
# Let's plot the ranking.

# %%
sm.plot_bar(df, "Rank")

# %% [markdown]
# To write a metric dataframe to disk, encode the dataframe as a pickle object.

# %%
PATH = "./metrics_dataframe.pkl"

sm.to_pickle(df, PATH)
sm.show(sm.read_pickle(PATH), color_style="gradient")
# Out:
# <style type="text/css">
# #T_6e7e8 th.col_heading {
#   text-align: center;
# }
# #T_6e7e8 td {
#   border-right: 1px solid #ccc;
# }
# #T_6e7e8 th.row_heading {
#   border-right: 1px solid #ccc;
# }
# #T_6e7e8_row0_col0, #T_6e7e8_row0_col1, #T_6e7e8_row0_col3, #T_6e7e8_row1_col0, #T_6e7e8_row1_col2, #T_6e7e8_row1_col4, #T_6e7e8_row1_col5, #T_6e7e8_row1_col6, #T_6e7e8_row2_col1, #T_6e7e8_row3_col0, #T_6e7e8_row3_col1 {
#   background-color: #68d6bcff;
#   font-weight: bold;
# }
# #T_6e7e8_row0_col2 {
#   background-color: #68d6bc91;
#   text-decoration: underline;
# }
# #T_6e7e8_row0_col4 {
#   background-color: #68d6bc74;
#   text-decoration: underline;
# }
# #T_6e7e8_row0_col5 {
#   background-color: #68d6bca8;
#   text-decoration: underline;
# }
# #T_6e7e8_row0_col6 {
#   background-color: #68d6bc80;
#   text-decoration: underline;
# }
# #T_6e7e8_row1_col1, #T_6e7e8_row2_col0, #T_6e7e8_row2_col2, #T_6e7e8_row2_col3, #T_6e7e8_row2_col5, #T_6e7e8_row2_col6, #T_6e7e8_row3_col4, #T_6e7e8_row3_col5, #T_6e7e8_row3_col6 {
#   background-color: #68d6bc00;
# }
# #T_6e7e8_row1_col3 {
#   background-color: #68d6bc8a;
#   text-decoration: underline;
# }
# #T_6e7e8_row2_col4 {
#   background-color: #68d6bc24;
# }
# #T_6e7e8_row3_col2 {
#   background-color: #68d6bc55;
# }
# #T_6e7e8_row3_col3 {
#   background-color: #68d6bc0b;
# }
# </style>
# <table id="T_6e7e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e7e8_level0_col0" class="col_heading level0 col0" >Uniqueness↑</th>
#       <th id="T_6e7e8_level0_col1" class="col_heading level0 col1" >Novelty (UniProt)↑</th>
#       <th id="T_6e7e8_level0_col2" class="col_heading level0 col2" >Diversity↑</th>
#       <th id="T_6e7e8_level0_col3" class="col_heading level0 col3" >FBD↓</th>
#       <th id="T_6e7e8_level0_col4" class="col_heading level0 col4" >Gravy↓</th>
#       <th id="T_6e7e8_level0_col5" class="col_heading level0 col5" >Hit-rate↑</th>
#       <th id="T_6e7e8_level0_col6" class="col_heading level0 col6" >Rank↓</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e7e8_level0_row0" class="row_heading level0 row0" >Random</th>
#       <td id="T_6e7e8_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_6e7e8_row0_col1" class="data row0 col1" >1.00</td>
#       <td id="T_6e7e8_row0_col2" class="data row0 col2" >0.87</td>
#       <td id="T_6e7e8_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_6e7e8_row0_col4" class="data row0 col4" >-1.91±1.46</td>
#       <td id="T_6e7e8_row0_col5" class="data row0 col5" >0.33</td>
#       <td id="T_6e7e8_row0_col6" class="data row0 col6" >2.00</td>
#     </tr>
#     <tr>
#       <th id="T_6e7e8_level0_row1" class="row_heading level0 row1" >UniProt</th>
#       <td id="T_6e7e8_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_6e7e8_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_6e7e8_row1_col2" class="data row1 col2" >1.00</td>
#       <td id="T_6e7e8_row1_col3" class="data row1 col3" >3.96</td>
#       <td id="T_6e7e8_row1_col4" class="data row1 col4" >-2.40±0.65</td>
#       <td id="T_6e7e8_row1_col5" class="data row1 col5" >0.50</td>
#       <td id="T_6e7e8_row1_col6" class="data row1 col6" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_6e7e8_level0_row2" class="row_heading level0 row2" >HydrAMP</th>
#       <td id="T_6e7e8_row2_col0" class="data row2 col0" >0.75</td>
#       <td id="T_6e7e8_row2_col1" class="data row2 col1" >1.00</td>
#       <td id="T_6e7e8_row2_col2" class="data row2 col2" >0.70</td>
#       <td id="T_6e7e8_row2_col3" class="data row2 col3" >8.60</td>
#       <td id="T_6e7e8_row2_col4" class="data row2 col4" >-1.63±0.36</td>
#       <td id="T_6e7e8_row2_col5" class="data row2 col5" >0.00</td>
#       <td id="T_6e7e8_row2_col6" class="data row2 col6" >3.00</td>
#     </tr>
#     <tr>
#       <th id="T_6e7e8_level0_row3" class="row_heading level0 row3" >hyformer</th>
#       <td id="T_6e7e8_row3_col0" class="data row3 col0" >1.00</td>
#       <td id="T_6e7e8_row3_col1" class="data row3 col1" >1.00</td>
#       <td id="T_6e7e8_row3_col2" class="data row3 col2" >0.80</td>
#       <td id="T_6e7e8_row3_col3" class="data row3 col3" >8.23</td>
#       <td id="T_6e7e8_row3_col4" class="data row3 col4" >-1.50±0.10</td>
#       <td id="T_6e7e8_row3_col5" class="data row3 col5" >0.00</td>
#       <td id="T_6e7e8_row3_col6" class="data row3 col6" >3.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# It is also possible to export the dataframe to a LaTeX table or a PNG as shown below.
#
# To save the styled metric dataframe to a png, we use `dataframe_image`.

# %%
# !pip install dataframe_image

# %%
SAVE_TABLE = True

if SAVE_TABLE:
    # save to LaTeX
    sm.to_latex(df, "table.tex", n_decimals=3, color=None, caption="My first table")

    # save to PNG
    import dataframe_image as dfi

    styler = sm.show(df, n_decimals=3, color_style="bar")
    await dfi.export_async(styler, "table.png", dpi=300)

# %% [markdown]
# That it all for the basic usage of seqme. Check out the documentation for the [metrics](https://seqme.readthedocs.io/en/stable/api/metrics_index.html) and [models](https://seqme.readthedocs.io/en/stable/api/models_index.html) implemented in seqme.
#
# Let's now look at some more advanced features!

# %% [markdown]
# ## Advanced

# %% [markdown]
# In the advanced section, we show how to
#
# - Combine multiple metric dataframes into one.
# - Improve performance through caching.
# - Create your own metric.

# %% [markdown]
# ### Combining metric dataframes
#
# seqme's `combine` can combine metric dataframes with different sequences and/or metrics. This can be useful if you want to evaluate the sequences on an additional metric or add an additional set of sequences for evaluation - without needing to recompute the results.

# %% [markdown]
# Let's create three metric dataframes.

# %%
df1 = sm.evaluate(
    sequences={
        "s1": ["KKKKK", "PLUQ", "RKSPL"],
        "s2": sm.utils.subsample(["KKWQ", "RKSPL", "RASD"], n_samples=2, seed=42),
        "s3": ["MMRK", "RKSPL", "RRLSK"],
        "s4": ["MKQW", "RKSPL"],
    },
    metrics=[
        sm.metrics.Novelty(reference=["KKW", "RKSPL"]),
        sm.metrics.Novelty(reference=["RASD", "KKKQ", "LPTUY"], name="Novelty (Random)"),
    ],
    verbose=False,
)

df2 = sm.evaluate(
    sequences={"s4": ["MKQW", "RKSPL"], "s5": ["MKQW"]},
    metrics=[sm.metrics.ID(sm.models.Gravy(), name="Gravy", objective="minimize")],
    verbose=False,
)

df3 = sm.evaluate(
    sequences={"s6": ["MKQW", "RKSPL"]},
    metrics=[
        sm.metrics.ID(sm.models.Gravy(), name="Gravy", objective="minimize"),
        sm.metrics.Novelty(reference=["KKW", "RKSPL"]),
    ],
    verbose=False,
)

# %% [markdown]
# Let's combine the dataframes.

# %%
df = sm.combine([df1, df2, df3])

# %%
df
# Out:
#      Novelty           Novelty (Random)           Gravy
#        value deviation            value deviation value deviation
# s1  0.666667       NaN              1.0       NaN   NaN       NaN
# s2  1.000000       NaN              0.5       NaN   NaN       NaN
# s3  0.666667       NaN              1.0       NaN   NaN       NaN
# s4  0.500000       NaN              1.0       NaN  -1.5       0.1
# s5       NaN       NaN              NaN       NaN  -1.6       NaN
# s6  0.500000       NaN              NaN       NaN  -1.5       0.1

# %% [markdown]
# ... let's make it nicer to look at.

# %%
sm.show(df, n_decimals=[3, 2, 1], color="#d66868")
# Out:
# <style type="text/css">
# #T_53d24 th.col_heading {
#   text-align: center;
# }
# #T_53d24 td {
#   border-right: 1px solid #ccc;
# }
# #T_53d24 th.row_heading {
#   border-right: 1px solid #ccc;
# }
# #T_53d24_row0_col0, #T_53d24_row2_col0, #T_53d24_row3_col2, #T_53d24_row5_col2 {
#   text-decoration: underline;
# }
# #T_53d24_row0_col1, #T_53d24_row1_col0, #T_53d24_row2_col1, #T_53d24_row3_col1, #T_53d24_row4_col2 {
#   background-color: #d66868;
#   font-weight: bold;
# }
# </style>
# <table id="T_53d24">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53d24_level0_col0" class="col_heading level0 col0" >Novelty↑</th>
#       <th id="T_53d24_level0_col1" class="col_heading level0 col1" >Novelty (Random)↑</th>
#       <th id="T_53d24_level0_col2" class="col_heading level0 col2" >Gravy↓</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53d24_level0_row0" class="row_heading level0 row0" >s1</th>
#       <td id="T_53d24_row0_col0" class="data row0 col0" >0.667</td>
#       <td id="T_53d24_row0_col1" class="data row0 col1" >1.00</td>
#       <td id="T_53d24_row0_col2" class="data row0 col2" >-</td>
#     </tr>
#     <tr>
#       <th id="T_53d24_level0_row1" class="row_heading level0 row1" >s2</th>
#       <td id="T_53d24_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_53d24_row1_col1" class="data row1 col1" >0.50</td>
#       <td id="T_53d24_row1_col2" class="data row1 col2" >-</td>
#     </tr>
#     <tr>
#       <th id="T_53d24_level0_row2" class="row_heading level0 row2" >s3</th>
#       <td id="T_53d24_row2_col0" class="data row2 col0" >0.667</td>
#       <td id="T_53d24_row2_col1" class="data row2 col1" >1.00</td>
#       <td id="T_53d24_row2_col2" class="data row2 col2" >-</td>
#     </tr>
#     <tr>
#       <th id="T_53d24_level0_row3" class="row_heading level0 row3" >s4</th>
#       <td id="T_53d24_row3_col0" class="data row3 col0" >0.500</td>
#       <td id="T_53d24_row3_col1" class="data row3 col1" >1.00</td>
#       <td id="T_53d24_row3_col2" class="data row3 col2" >-1.5±0.1</td>
#     </tr>
#     <tr>
#       <th id="T_53d24_level0_row4" class="row_heading level0 row4" >s5</th>
#       <td id="T_53d24_row4_col0" class="data row4 col0" >-</td>
#       <td id="T_53d24_row4_col1" class="data row4 col1" >-</td>
#       <td id="T_53d24_row4_col2" class="data row4 col2" >-1.6</td>
#     </tr>
#     <tr>
#       <th id="T_53d24_level0_row5" class="row_heading level0 row5" >s6</th>
#       <td id="T_53d24_row5_col0" class="data row5 col0" >0.500</td>
#       <td id="T_53d24_row5_col1" class="data row5 col1" >-</td>
#       <td id="T_53d24_row5_col2" class="data row5 col2" >-1.5±0.1</td>
#     </tr>
#   </tbody>
# </table>

# %%
sm.plot_bar(df, "Novelty", color="#d66868", ylim=(0.0, 1.1), xticks_rotation=0.0)

# %% [markdown]
# Notice missing values (e.g., "Novelty" for "s5") are not shown in the barplot.

# %% [markdown]
# ### Caching
#
# Discriminators and embedders can be computational expensive to execute. To reduce the number of function evaluations for these models, we can cache the results of discriminators and embedders.
#
# The cache works like this: If a (sequence, embedding)-pair is already stored in the cache then retrieve the embedding. Otherwise compute the embedding, store the pair in the cache and retrieve the embedding.
#
# Let's create two toy models and the cache.

# %%
def my_embedder(sequences: list[str]) -> np.ndarray:
    lengths = [len(sequence) for sequence in sequences]
    counts = [sequence.count("K") for sequence in sequences]
    return np.array([lengths, counts], dtype=float).T


def my_discriminator(sequences: list[str]) -> np.ndarray:
    return np.ones(len(sequences)) * 0.85


cache = sm.Cache(models={"embedder": my_embedder, "discriminator": my_discriminator})

# %% [markdown]
# Optional: We can manually add model outputs to the cache. This is useful when e.g., (sequence, embedding)-pairs are already pre-computed and stored in a file.

# %%
seqs = ["MKQW", "AA", "BB"]
reps = my_embedder(seqs)

pairs = dict(zip(seqs, reps, strict=True))

cache.add(model_name="embedder", element=pairs)

# %% [markdown]
# Let's compute the metrics. Since both the `Precision` and `Recall` metric use the same embedding model (`embedder`), the embedding is only computed once per sequence in `sequences` (instead of twice)!
#
# Notice, we now use `cache.model()` instead of the embedder reference (`my_embedder`) directly.

# %%
df = sm.evaluate(
    sequences={
        "hyformer": ["RMKQW", "RKSPL", "RRRASD"],
        "HydrAMP": ["MKQW", "RKSPLP"],
        "Random": ["AAA", "PPPPP"],
    },
    metrics=[
        sm.metrics.Precision(
            reference=["AKWR", "AKKR", "KKKK"],
            embedder=cache.model("embedder"),
            n_neighbors=1,
            strict=False,
        ),
        sm.metrics.Recall(
            reference=["AKWR", "AKKR", "KKKK"],
            embedder=cache.model("embedder"),
            n_neighbors=1,
            strict=False,
        ),
    ],
)

sm.show(df, color="#69bce8")
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 272.24it/s, data=Random, metric=Recall]
# <style type="text/css">
# #T_f390c th.col_heading {
#   text-align: center;
# }
# #T_f390c td {
#   border-right: 1px solid #ccc;
# }
# #T_f390c th.row_heading {
#   border-right: 1px solid #ccc;
# }
# #T_f390c_row0_col0, #T_f390c_row1_col1 {
#   background-color: #69bce8;
#   font-weight: bold;
# }
# #T_f390c_row1_col0, #T_f390c_row2_col1 {
#   text-decoration: underline;
# }
# </style>
# <table id="T_f390c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f390c_level0_col0" class="col_heading level0 col0" >Precision↑</th>
#       <th id="T_f390c_level0_col1" class="col_heading level0 col1" >Recall↑</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f390c_level0_row0" class="row_heading level0 row0" >hyformer</th>
#       <td id="T_f390c_row0_col0" class="data row0 col0" >0.67</td>
#       <td id="T_f390c_row0_col1" class="data row0 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_f390c_level0_row1" class="row_heading level0 row1" >HydrAMP</th>
#       <td id="T_f390c_row1_col0" class="data row1 col0" >0.50</td>
#       <td id="T_f390c_row1_col1" class="data row1 col1" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_f390c_level0_row2" class="row_heading level0 row2" >Random</th>
#       <td id="T_f390c_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_f390c_row2_col1" class="data row2 col1" >0.33</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's plot a scatterplot of the metrics.

# %%
sm.plot_scatter(df)

# %% [markdown]
# Let's write the cached (sequence, embedding)-pairs for each model to a file and reinitialize the cache.

# %%
PATH = "precomputed.pkl"

sm.to_pickle(cache.get(), PATH)

precomputed = sm.read_pickle(PATH)

cache = sm.Cache(init_cache=precomputed)
pprint(cache.get())
# Out:
# {'discriminator': {},
#  'embedder': {'AA': array([2., 0.]),
#               'AAA': array([3., 0.]),
#               'AKKR': array([4., 2.]),
#               'AKWR': array([4., 1.]),
#               'BB': array([2., 0.]),
#               'KKKK': array([4., 4.]),
#               'MKQW': array([4., 1.]),
#               'PPPPP': array([5., 0.]),
#               'RKSPL': array([5., 1.]),
#               'RKSPLP': array([6., 1.]),
#               'RMKQW': array([5., 1.]),
#               'RRRASD': array([6., 0.])}}

# %% [markdown]
# **Tip:**
# The cache can become very useful if you use an external tool to predict sequence properties, e.g., a command-line tool or a tool implemented in another programming language. Now you want to use these predictions in seqme to a compute metric. To do so, 1. read the predictions stored in a file and 2. pre-init the `Cache` with these (sequence, predictions)-pairs.

# %% [markdown]
# ### Creating a new metric

# %% [markdown]
# You can also integrate your own metrics into seqme through the `Metric` interface as shown below.

# %%
class MyMetric(sm.Metric):
    def __init__(self, amino_acid: str, minimize: bool = True):
        self.amino_acid = amino_acid
        self.minimize = minimize

    def __call__(self, sequences: list[str]) -> sm.MetricResult:
        aa_count = sum([seq.count(self.amino_acid) for seq in sequences])
        aa_total = sum([len(sequence) for sequence in sequences])
        return sm.MetricResult(aa_count / aa_total)

    @property
    def name(self) -> str:
        return f"{self.amino_acid}-frequency"

    @property
    def objective(self) -> Literal["minimize", "maximize"]:
        return "minimize" if self.minimize else "maximize"

# %% [markdown]
# Let's use our new metric.

# %%
df = sm.evaluate(
    sequences={
        "hyformer": ["MKQW", "RKSPL", "RASD"],
        "HydrAMP": ["MKQW", "RKSPL"],
        "Random": ["AAAA", "PPPPP"],
    },
    metrics=[
        MyMetric(amino_acid="K", minimize=False),
        MyMetric(amino_acid="R", minimize=True),
    ],
)

sm.show(df, color="#e07fe1", color_style="bar", caption="Table 1. Our first metric 🎉")
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 57.36it/s, data=Random, metric=R-frequency]
# <style type="text/css">
# #T_6e138 th.col_heading {
#   text-align: center;
# }
# #T_6e138 td {
#   border-right: 1px solid #ccc;
# }
# #T_6e138 th.row_heading {
#   border-right: 1px solid #ccc;
# }
# #T_6e138 caption {
#   caption-side: bottom;
#   margin-top: 0.75em;
# }
# #T_6e138_row0_col0 {
#   background: linear-gradient(90deg, #e07fe1 68.2%, transparent 68.2%);
#   text-decoration: underline;
# }
# #T_6e138_row1_col0, #T_6e138_row2_col1 {
#   background: linear-gradient(90deg, #e07fe1 100.0%, transparent 100.0%);
#   font-weight: bold;
# }
# #T_6e138_row1_col1 {
#   background: linear-gradient(90deg, #e07fe1 26.7%, transparent 26.7%);
#   text-decoration: underline;
# }
# </style>
# <table id="T_6e138">
#   <caption>Table 1. Our first metric 🎉</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e138_level0_col0" class="col_heading level0 col0" >K-frequency↑</th>
#       <th id="T_6e138_level0_col1" class="col_heading level0 col1" >R-frequency↓</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e138_level0_row0" class="row_heading level0 row0" >hyformer</th>
#       <td id="T_6e138_row0_col0" class="data row0 col0" >0.15</td>
#       <td id="T_6e138_row0_col1" class="data row0 col1" >0.15</td>
#     </tr>
#     <tr>
#       <th id="T_6e138_level0_row1" class="row_heading level0 row1" >HydrAMP</th>
#       <td id="T_6e138_row1_col0" class="data row1 col0" >0.22</td>
#       <td id="T_6e138_row1_col1" class="data row1 col1" >0.11</td>
#     </tr>
#     <tr>
#       <th id="T_6e138_level0_row2" class="row_heading level0 row2" >Random</th>
#       <td id="T_6e138_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_6e138_row2_col1" class="data row2 col1" >0.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We have now covered the main functionality of seqme! 🎉
#
# seqme also contains functionality to add third-party models, evaluate embedding models alignment with the property/properties of interest and a few extra things.
