# %% [markdown]
# # Evaluating iterative algorithms

# %% [markdown]
# Many generative methods (e.g., genetic algorithms) iteratively explore sequences to improve sequence fitness. In this notebook, we show on toy sequences how to evaluate sequences optimized across multiple rounds and visualize the results using seqme.

# %%
import seqme as sm

# %% [markdown]
# ## Single run

# %% [markdown]
# seqme allows naming sequence entries as a tuple. Here we name an entry using the following format: (model name, iteration).

# %%
sequences = {
    ("model 1", 1): ["QLF", "FFQLL", "RQLL"],
    ("model 1", 2): ["RQLF", "PRFQRP", "RQLL"],
    ("model 1", 3): ["RQLRR", "RQLRRR", "RQLRRR"],
    ("model 2", 1): ["QLF", "QLF", "RQLL"],
    ("model 2", 2): ["QLF", "FFQRP", "RQLL"],
    ("model 2", 3): ["PLFR", "RFQRP", "RQLR"],
}

# %% [markdown]
# Let's define the metrics to compute.

# %%
metrics = [
    sm.metrics.ID(predictor=sm.models.Charge(), name="Charge", objective="maximize"),
    sm.metrics.ID(predictor=sm.models.Hydrophobicity(), name="Hydrophobicity", objective="maximize"),
    sm.metrics.Uniqueness(),
]

# %% [markdown]
# Let's compute the metrics.

# %%
df = sm.evaluate(sequences, metrics)
# Out:
# 100%|██████████| 18/18 [00:00<00:00, 377.75it/s, data=('model 2', 3), metric=Uniqueness]

# %%
sm.show(df, color_style="bar", caption="Table 1.1 Iterative algorithms")
# Out:
# <style type="text/css">
# #T_aebc7 th.col_heading {
#   text-align: center;
# }
# #T_aebc7 td {
#   border-right: 1px solid #ccc;
# }
# #T_aebc7 th.row_heading {
#   border-right: 1px solid #ccc;
# }
# #T_aebc7 tbody tr:nth-child(4) td {
#   border-top: 1px solid #ccc;
# }
# #T_aebc7  tbody tr:nth-child(4) th {
#   border-top: 1px solid #ccc;
# }
# #T_aebc7 caption {
#   caption-side: bottom;
#   margin-top: 0.75em;
# }
# #T_aebc7_row0_col1, #T_aebc7_row0_col2, #T_aebc7_row1_col2, #T_aebc7_row2_col0, #T_aebc7_row4_col2, #T_aebc7_row5_col2 {
#   background: linear-gradient(90deg, #68d6bc 100.0%, transparent 100.0%);
#   font-weight: bold;
# }
# #T_aebc7_row1_col0 {
#   background: linear-gradient(90deg, #68d6bc 30.0%, transparent 30.0%);
# }
# #T_aebc7_row1_col1 {
#   background: linear-gradient(90deg, #68d6bc 60.3%, transparent 60.3%);
# }
# #T_aebc7_row3_col1 {
#   background: linear-gradient(90deg, #68d6bc 95.2%, transparent 95.2%);
#   text-decoration: underline;
# }
# #T_aebc7_row4_col0 {
#   background: linear-gradient(90deg, #68d6bc 9.9%, transparent 9.9%);
# }
# #T_aebc7_row4_col1 {
#   background: linear-gradient(90deg, #68d6bc 83.6%, transparent 83.6%);
# }
# #T_aebc7_row5_col0 {
#   background: linear-gradient(90deg, #68d6bc 39.9%, transparent 39.9%);
#   text-decoration: underline;
# }
# #T_aebc7_row5_col1 {
#   background: linear-gradient(90deg, #68d6bc 46.0%, transparent 46.0%);
# }
# </style>
# <table id="T_aebc7">
#   <caption>Table 1.1 Iterative algorithms</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aebc7_level0_col0" class="col_heading level0 col0" >Charge↑</th>
#       <th id="T_aebc7_level0_col1" class="col_heading level0 col1" >Hydrophobicity↑</th>
#       <th id="T_aebc7_level0_col2" class="col_heading level0 col2" >Uniqueness↑</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aebc7_level0_row0" class="row_heading level0 row0" rowspan="3">model 1</th>
#       <th id="T_aebc7_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_aebc7_row0_col0" class="data row0 col0" >0.33±0.47</td>
#       <td id="T_aebc7_row0_col1" class="data row0 col1" >0.32±0.44</td>
#       <td id="T_aebc7_row0_col2" class="data row0 col2" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_aebc7_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_aebc7_row1_col0" class="data row1 col0" >1.33±0.47</td>
#       <td id="T_aebc7_row1_col1" class="data row1 col1" >-0.43±0.22</td>
#       <td id="T_aebc7_row1_col2" class="data row1 col2" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_aebc7_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_aebc7_row2_col0" class="data row2 col0" >3.66±0.47</td>
#       <td id="T_aebc7_row2_col1" class="data row2 col1" >-1.57±0.08</td>
#       <td id="T_aebc7_row2_col2" class="data row2 col2" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_aebc7_level0_row3" class="row_heading level0 row3" rowspan="3">model 2</th>
#       <th id="T_aebc7_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_aebc7_row3_col0" class="data row3 col0" >0.33±0.47</td>
#       <td id="T_aebc7_row3_col1" class="data row3 col1" >0.23±0.36</td>
#       <td id="T_aebc7_row3_col2" class="data row3 col2" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_aebc7_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_aebc7_row4_col0" class="data row4 col0" >0.66±0.47</td>
#       <td id="T_aebc7_row4_col1" class="data row4 col1" >0.01±0.34</td>
#       <td id="T_aebc7_row4_col2" class="data row4 col2" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_aebc7_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_aebc7_row5_col0" class="data row5 col0" >1.66±0.47</td>
#       <td id="T_aebc7_row5_col1" class="data row5 col1" >-0.70±0.50</td>
#       <td id="T_aebc7_row5_col2" class="data row5 col2" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's highlight it differently.

# %%
sm.show(df, color_style="bar", caption="Table 1.2 Iterative algorithms", level=1)
# Out:
# <style type="text/css">
# #T_77495 th.col_heading {
#   text-align: center;
# }
# #T_77495 td {
#   border-right: 1px solid #ccc;
# }
# #T_77495 th.row_heading {
#   border-right: 1px solid #ccc;
# }
# #T_77495 tbody tr:nth-child(4) td {
#   border-top: 1px solid #ccc;
# }
# #T_77495  tbody tr:nth-child(4) th {
#   border-top: 1px solid #ccc;
# }
# #T_77495 caption {
#   caption-side: bottom;
#   margin-top: 0.75em;
# }
# #T_77495_row0_col1, #T_77495_row0_col2, #T_77495_row1_col2, #T_77495_row2_col0, #T_77495_row3_col1, #T_77495_row4_col2, #T_77495_row5_col0, #T_77495_row5_col2 {
#   background: linear-gradient(90deg, #68d6bc 100.0%, transparent 100.0%);
#   font-weight: bold;
# }
# #T_77495_row1_col0 {
#   background: linear-gradient(90deg, #68d6bc 30.0%, transparent 30.0%);
#   text-decoration: underline;
# }
# #T_77495_row1_col1 {
#   background: linear-gradient(90deg, #68d6bc 60.3%, transparent 60.3%);
#   text-decoration: underline;
# }
# #T_77495_row4_col0 {
#   background: linear-gradient(90deg, #68d6bc 24.8%, transparent 24.8%);
#   text-decoration: underline;
# }
# #T_77495_row4_col1 {
#   background: linear-gradient(90deg, #68d6bc 76.3%, transparent 76.3%);
#   text-decoration: underline;
# }
# </style>
# <table id="T_77495">
#   <caption>Table 1.2 Iterative algorithms</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77495_level0_col0" class="col_heading level0 col0" >Charge↑</th>
#       <th id="T_77495_level0_col1" class="col_heading level0 col1" >Hydrophobicity↑</th>
#       <th id="T_77495_level0_col2" class="col_heading level0 col2" >Uniqueness↑</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77495_level0_row0" class="row_heading level0 row0" rowspan="3">model 1</th>
#       <th id="T_77495_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_77495_row0_col0" class="data row0 col0" >0.33±0.47</td>
#       <td id="T_77495_row0_col1" class="data row0 col1" >0.32±0.44</td>
#       <td id="T_77495_row0_col2" class="data row0 col2" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_77495_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_77495_row1_col0" class="data row1 col0" >1.33±0.47</td>
#       <td id="T_77495_row1_col1" class="data row1 col1" >-0.43±0.22</td>
#       <td id="T_77495_row1_col2" class="data row1 col2" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_77495_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_77495_row2_col0" class="data row2 col0" >3.66±0.47</td>
#       <td id="T_77495_row2_col1" class="data row2 col1" >-1.57±0.08</td>
#       <td id="T_77495_row2_col2" class="data row2 col2" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_77495_level0_row3" class="row_heading level0 row3" rowspan="3">model 2</th>
#       <th id="T_77495_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_77495_row3_col0" class="data row3 col0" >0.33±0.47</td>
#       <td id="T_77495_row3_col1" class="data row3 col1" >0.23±0.36</td>
#       <td id="T_77495_row3_col2" class="data row3 col2" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_77495_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_77495_row4_col0" class="data row4 col0" >0.66±0.47</td>
#       <td id="T_77495_row4_col1" class="data row4 col1" >0.01±0.34</td>
#       <td id="T_77495_row4_col2" class="data row4 col2" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_77495_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_77495_row5_col0" class="data row5 col0" >1.66±0.47</td>
#       <td id="T_77495_row5_col1" class="data row5 col1" >-0.70±0.50</td>
#       <td id="T_77495_row5_col2" class="data row5 col2" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Notice in the above table visualization, we set `level=1`, this means that each sub metric dataframe (model 1 and model 2) should be colored, underlined and bolded, independently.

# %% [markdown]
# Let's visualize the sequences performance at each step.

# %%
sm.plot_line(df, metric="Charge")

# %% [markdown]
# Let's look at two metrics.

# %%
sm.plot_scatter(df, metrics=["Charge", "Hydrophobicity"])

# %%
sm.plot_scatter(df[["Charge", "Uniqueness"]])

# %% [markdown]
# Let's sort the sequences by their charge.

# %%
df2 = sm.sort(df, "Charge", level=0)
sm.show(df2, caption="Table 2.1. Iterative algorithms (sorted)", color_style="bar", hline_level=0)
# Out:
# <style type="text/css">
# #T_65bd6 th.col_heading {
#   text-align: center;
# }
# #T_65bd6 td {
#   border-right: 1px solid #ccc;
# }
# #T_65bd6 th.row_heading {
#   border-right: 1px solid #ccc;
# }
# #T_65bd6 caption {
#   caption-side: bottom;
#   margin-top: 0.75em;
# }
# #T_65bd6_row0_col0, #T_65bd6_row1_col2, #T_65bd6_row2_col2, #T_65bd6_row3_col2, #T_65bd6_row4_col1, #T_65bd6_row4_col2 {
#   background: linear-gradient(90deg, #68d6bc 100.0%, transparent 100.0%);
#   font-weight: bold;
# }
# #T_65bd6_row1_col0 {
#   background: linear-gradient(90deg, #68d6bc 39.9%, transparent 39.9%);
#   text-decoration: underline;
# }
# #T_65bd6_row1_col1 {
#   background: linear-gradient(90deg, #68d6bc 46.0%, transparent 46.0%);
# }
# #T_65bd6_row2_col0 {
#   background: linear-gradient(90deg, #68d6bc 30.0%, transparent 30.0%);
# }
# #T_65bd6_row2_col1 {
#   background: linear-gradient(90deg, #68d6bc 60.3%, transparent 60.3%);
# }
# #T_65bd6_row3_col0 {
#   background: linear-gradient(90deg, #68d6bc 9.9%, transparent 9.9%);
# }
# #T_65bd6_row3_col1 {
#   background: linear-gradient(90deg, #68d6bc 83.6%, transparent 83.6%);
# }
# #T_65bd6_row5_col1 {
#   background: linear-gradient(90deg, #68d6bc 95.2%, transparent 95.2%);
#   text-decoration: underline;
# }
# </style>
# <table id="T_65bd6">
#   <caption>Table 2.1. Iterative algorithms (sorted)</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65bd6_level0_col0" class="col_heading level0 col0" >Charge↑</th>
#       <th id="T_65bd6_level0_col1" class="col_heading level0 col1" >Hydrophobicity↑</th>
#       <th id="T_65bd6_level0_col2" class="col_heading level0 col2" >Uniqueness↑</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65bd6_level0_row0" class="row_heading level0 row0" >model 1</th>
#       <th id="T_65bd6_level1_row0" class="row_heading level1 row0" >3</th>
#       <td id="T_65bd6_row0_col0" class="data row0 col0" >3.66±0.47</td>
#       <td id="T_65bd6_row0_col1" class="data row0 col1" >-1.57±0.08</td>
#       <td id="T_65bd6_row0_col2" class="data row0 col2" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_65bd6_level0_row1" class="row_heading level0 row1" >model 2</th>
#       <th id="T_65bd6_level1_row1" class="row_heading level1 row1" >3</th>
#       <td id="T_65bd6_row1_col0" class="data row1 col0" >1.66±0.47</td>
#       <td id="T_65bd6_row1_col1" class="data row1 col1" >-0.70±0.50</td>
#       <td id="T_65bd6_row1_col2" class="data row1 col2" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_65bd6_level0_row2" class="row_heading level0 row2" >model 1</th>
#       <th id="T_65bd6_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_65bd6_row2_col0" class="data row2 col0" >1.33±0.47</td>
#       <td id="T_65bd6_row2_col1" class="data row2 col1" >-0.43±0.22</td>
#       <td id="T_65bd6_row2_col2" class="data row2 col2" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_65bd6_level0_row3" class="row_heading level0 row3" >model 2</th>
#       <th id="T_65bd6_level1_row3" class="row_heading level1 row3" >2</th>
#       <td id="T_65bd6_row3_col0" class="data row3 col0" >0.66±0.47</td>
#       <td id="T_65bd6_row3_col1" class="data row3 col1" >0.01±0.34</td>
#       <td id="T_65bd6_row3_col2" class="data row3 col2" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_65bd6_level0_row4" class="row_heading level0 row4" >model 1</th>
#       <th id="T_65bd6_level1_row4" class="row_heading level1 row4" >1</th>
#       <td id="T_65bd6_row4_col0" class="data row4 col0" >0.33±0.47</td>
#       <td id="T_65bd6_row4_col1" class="data row4 col1" >0.32±0.44</td>
#       <td id="T_65bd6_row4_col2" class="data row4 col2" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_65bd6_level0_row5" class="row_heading level0 row5" >model 2</th>
#       <th id="T_65bd6_level1_row5" class="row_heading level1 row5" >1</th>
#       <td id="T_65bd6_row5_col0" class="data row5 col0" >0.33±0.47</td>
#       <td id="T_65bd6_row5_col1" class="data row5 col1" >0.23±0.36</td>
#       <td id="T_65bd6_row5_col2" class="data row5 col2" >0.67</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's rearrange the entries levels and sort the sequence by uniqueness within each iteration.

# %%
df3 = df.reorder_levels([1, 0])
df3 = sm.sort(df3, "Uniqueness", level=1)

sm.show(
    df3, color="#d668c9", caption="Table 2.2. Iterative algorithms (sorted within iteration)", color_style="gradient"
)
# Out:
# <style type="text/css">
# #T_6437c th.col_heading {
#   text-align: center;
# }
# #T_6437c td {
#   border-right: 1px solid #ccc;
# }
# #T_6437c th.row_heading {
#   border-right: 1px solid #ccc;
# }
# #T_6437c tbody tr:nth-child(3) td {
#   border-top: 1px solid #ccc;
# }
# #T_6437c  tbody tr:nth-child(3) th {
#   border-top: 1px solid #ccc;
# }
# #T_6437c tbody tr:nth-child(5) td {
#   border-top: 1px solid #ccc;
# }
# #T_6437c  tbody tr:nth-child(5) th {
#   border-top: 1px solid #ccc;
# }
# #T_6437c caption {
#   caption-side: bottom;
#   margin-top: 0.75em;
# }
# #T_6437c_row0_col0, #T_6437c_row1_col0, #T_6437c_row1_col2, #T_6437c_row5_col1, #T_6437c_row5_col2 {
#   background-color: #d668c900;
# }
# #T_6437c_row0_col1, #T_6437c_row0_col2, #T_6437c_row2_col2, #T_6437c_row3_col2, #T_6437c_row4_col2, #T_6437c_row5_col0 {
#   background-color: #d668c9ff;
#   font-weight: bold;
# }
# #T_6437c_row1_col1 {
#   background-color: #d668c9f3;
#   text-decoration: underline;
# }
# #T_6437c_row2_col0 {
#   background-color: #d668c94c;
# }
# #T_6437c_row2_col1 {
#   background-color: #d668c99a;
# }
# #T_6437c_row3_col0 {
#   background-color: #d668c919;
# }
# #T_6437c_row3_col1 {
#   background-color: #d668c9d6;
# }
# #T_6437c_row4_col0 {
#   background-color: #d668c966;
#   text-decoration: underline;
# }
# #T_6437c_row4_col1 {
#   background-color: #d668c975;
# }
# </style>
# <table id="T_6437c">
#   <caption>Table 2.2. Iterative algorithms (sorted within iteration)</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6437c_level0_col0" class="col_heading level0 col0" >Charge↑</th>
#       <th id="T_6437c_level0_col1" class="col_heading level0 col1" >Hydrophobicity↑</th>
#       <th id="T_6437c_level0_col2" class="col_heading level0 col2" >Uniqueness↑</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6437c_level0_row0" class="row_heading level0 row0" rowspan="2">1</th>
#       <th id="T_6437c_level1_row0" class="row_heading level1 row0" >model 1</th>
#       <td id="T_6437c_row0_col0" class="data row0 col0" >0.33±0.47</td>
#       <td id="T_6437c_row0_col1" class="data row0 col1" >0.32±0.44</td>
#       <td id="T_6437c_row0_col2" class="data row0 col2" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_6437c_level1_row1" class="row_heading level1 row1" >model 2</th>
#       <td id="T_6437c_row1_col0" class="data row1 col0" >0.33±0.47</td>
#       <td id="T_6437c_row1_col1" class="data row1 col1" >0.23±0.36</td>
#       <td id="T_6437c_row1_col2" class="data row1 col2" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_6437c_level0_row2" class="row_heading level0 row2" rowspan="2">2</th>
#       <th id="T_6437c_level1_row2" class="row_heading level1 row2" >model 1</th>
#       <td id="T_6437c_row2_col0" class="data row2 col0" >1.33±0.47</td>
#       <td id="T_6437c_row2_col1" class="data row2 col1" >-0.43±0.22</td>
#       <td id="T_6437c_row2_col2" class="data row2 col2" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_6437c_level1_row3" class="row_heading level1 row3" >model 2</th>
#       <td id="T_6437c_row3_col0" class="data row3 col0" >0.66±0.47</td>
#       <td id="T_6437c_row3_col1" class="data row3 col1" >0.01±0.34</td>
#       <td id="T_6437c_row3_col2" class="data row3 col2" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_6437c_level0_row4" class="row_heading level0 row4" rowspan="2">3</th>
#       <th id="T_6437c_level1_row4" class="row_heading level1 row4" >model 2</th>
#       <td id="T_6437c_row4_col0" class="data row4 col0" >1.66±0.47</td>
#       <td id="T_6437c_row4_col1" class="data row4 col1" >-0.70±0.50</td>
#       <td id="T_6437c_row4_col2" class="data row4 col2" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_6437c_level1_row5" class="row_heading level1 row5" >model 1</th>
#       <td id="T_6437c_row5_col0" class="data row5 col0" >3.66±0.47</td>
#       <td id="T_6437c_row5_col1" class="data row5 col1" >-1.57±0.08</td>
#       <td id="T_6437c_row5_col2" class="data row5 col2" >0.67</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's display the sequences with largest charge in each iteration.

# %%
df4 = df.reorder_levels([1, 0]).sort_index()
df4 = sm.top_k(df4, "Charge", k=1, level=1)
sm.show(df4, color_style="bar", hline_level=0, caption="Table 2.3. Best per iteration")
# Out:
# <style type="text/css">
# #T_1cc19 th.col_heading {
#   text-align: center;
# }
# #T_1cc19 td {
#   border-right: 1px solid #ccc;
# }
# #T_1cc19 th.row_heading {
#   border-right: 1px solid #ccc;
# }
# #T_1cc19 caption {
#   caption-side: bottom;
#   margin-top: 0.75em;
# }
# #T_1cc19_row0_col1, #T_1cc19_row0_col2, #T_1cc19_row2_col2, #T_1cc19_row3_col0 {
#   background: linear-gradient(90deg, #68d6bc 100.0%, transparent 100.0%);
#   font-weight: bold;
# }
# #T_1cc19_row1_col1 {
#   background: linear-gradient(90deg, #68d6bc 95.2%, transparent 95.2%);
#   text-decoration: underline;
# }
# #T_1cc19_row2_col0 {
#   background: linear-gradient(90deg, #68d6bc 30.0%, transparent 30.0%);
#   text-decoration: underline;
# }
# #T_1cc19_row2_col1 {
#   background: linear-gradient(90deg, #68d6bc 60.3%, transparent 60.3%);
# }
# </style>
# <table id="T_1cc19">
#   <caption>Table 2.3. Best per iteration</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1cc19_level0_col0" class="col_heading level0 col0" >Charge↑</th>
#       <th id="T_1cc19_level0_col1" class="col_heading level0 col1" >Hydrophobicity↑</th>
#       <th id="T_1cc19_level0_col2" class="col_heading level0 col2" >Uniqueness↑</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1cc19_level0_row0" class="row_heading level0 row0" rowspan="2">1</th>
#       <th id="T_1cc19_level1_row0" class="row_heading level1 row0" >model 1</th>
#       <td id="T_1cc19_row0_col0" class="data row0 col0" >0.33±0.47</td>
#       <td id="T_1cc19_row0_col1" class="data row0 col1" >0.32±0.44</td>
#       <td id="T_1cc19_row0_col2" class="data row0 col2" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_1cc19_level1_row1" class="row_heading level1 row1" >model 2</th>
#       <td id="T_1cc19_row1_col0" class="data row1 col0" >0.33±0.47</td>
#       <td id="T_1cc19_row1_col1" class="data row1 col1" >0.23±0.36</td>
#       <td id="T_1cc19_row1_col2" class="data row1 col2" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_1cc19_level0_row2" class="row_heading level0 row2" >2</th>
#       <th id="T_1cc19_level1_row2" class="row_heading level1 row2" >model 1</th>
#       <td id="T_1cc19_row2_col0" class="data row2 col0" >1.33±0.47</td>
#       <td id="T_1cc19_row2_col1" class="data row2 col1" >-0.43±0.22</td>
#       <td id="T_1cc19_row2_col2" class="data row2 col2" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_1cc19_level0_row3" class="row_heading level0 row3" >3</th>
#       <th id="T_1cc19_level1_row3" class="row_heading level1 row3" >model 1</th>
#       <td id="T_1cc19_row3_col0" class="data row3 col0" >3.66±0.47</td>
#       <td id="T_1cc19_row3_col1" class="data row3 col1" >-1.57±0.08</td>
#       <td id="T_1cc19_row3_col2" class="data row3 col2" >0.67</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Multiple runs

# %% [markdown]
# Let's assume we ran two generative models multiple times with a different seed each time. The sequences from the runs are shown below. And now we want to compute the deviation in performance across runs.

# %%
sequences_run1 = {
    ("model 1", 1): ["QLF", "FFQLL", "RQLL"],
    ("model 1", 2): ["RQLF", "PRFQRP", "RQLL"],
    ("model 1", 3): ["RQLRR", "RQLRRR", "RQLRRR"],
    ("model 2", 1): ["QLF", "FFQRP", "RQLL"],
    ("model 2", 2): ["QLF", "FFQRP", "RQLL"],
    ("model 2", 3): ["PLFR", "RFQRP", "RQLR"],
}

sequences_run2 = {
    ("model 1", 1): ["QLF", "FFQLL", "RQLL"],
    ("model 1", 2): ["RQLF", "PRFQRP", "RQLL"],
    ("model 1", 3): ["RQLRR", "RQLRRR", "RQLRRR"],
    ("model 2", 1): ["QLF", "FFQRP", "RQLL"],
    ("model 2", 2): ["QLF", "FFQRP", "RQLL"],
    ("model 2", 3): ["PLFR", "RFQRP", "RQLR"],
}

sequences_run3 = {
    ("model 1", 1): ["RQLF", "PRFQRP", "RQLL"],
    ("model 1", 2): ["QLF", "FFQLL", "RQLL"],
    ("model 1", 3): ["RQLRR", "RQLRRR", "RQLRRR"],
    ("model 2", 1): ["QLF", "FFQRP", "RQLL"],
    ("model 2", 2): ["QLF", "FFQRP", "RQLL"],
    ("model 2", 3): ["PLFR", "RFQRP", "RQLR"],
}

sequences_per_run = [sequences_run1, sequences_run2, sequences_run3]

# %% [markdown]
# Let's define the metrics to compute.

# %%
metrics = [
    sm.metrics.ID(predictor=sm.models.Charge(), name="Charge", objective="maximize"),
    sm.metrics.Uniqueness(),
]

# %%
df_per_run = [sm.evaluate(sequences, metrics) for sequences in sequences_per_run]
# Out:
#  92%|█████████▏| 11/12 [00:00<00:00, 336.25it/s, data=('model 2', 3), metric=Uniqueness]
# 100%|██████████| 12/12 [00:00<00:00, 362.21it/s, data=('model 2', 3), metric=Uniqueness]
# 100%|██████████| 12/12 [00:00<00:00, 1743.93it/s, data=('model 2', 3), metric=Uniqueness]
# 100%|██████████| 12/12 [00:00<00:00, 1282.17it/s, data=('model 2', 3), metric=Uniqueness]

# %% [markdown]
# Let's create a metric dataframe combining the metric dataframe of each run.

# %%
df_combined = sm.combine(df_per_run, on_overlap="mean,std")

# %% [markdown]
# Let's rank the models using all the metrics.

# %%
df_combined = sm.rank(df_combined, tiebreak="mean-rank")

# %%
sm.show(df_combined, color="#6892d6", color_style="bar", caption="Table 3.1. Multiple runs", n_decimals=[2, 2, 0])
# Out:
# <style type="text/css">
# #T_bda8f th.col_heading {
#   text-align: center;
# }
# #T_bda8f td {
#   border-right: 1px solid #ccc;
# }
# #T_bda8f th.row_heading {
#   border-right: 1px solid #ccc;
# }
# #T_bda8f tbody tr:nth-child(4) td {
#   border-top: 1px solid #ccc;
# }
# #T_bda8f  tbody tr:nth-child(4) th {
#   border-top: 1px solid #ccc;
# }
# #T_bda8f caption {
#   caption-side: bottom;
#   margin-top: 0.75em;
# }
# #T_bda8f_row0_col1, #T_bda8f_row1_col1, #T_bda8f_row2_col0, #T_bda8f_row3_col1, #T_bda8f_row4_col1, #T_bda8f_row5_col1, #T_bda8f_row5_col2 {
#   background: linear-gradient(90deg, #6892d6 100.0%, transparent 100.0%);
#   font-weight: bold;
# }
# #T_bda8f_row1_col0 {
#   background: linear-gradient(90deg, #6892d6 11.3%, transparent 11.3%);
# }
# #T_bda8f_row1_col2 {
#   background: linear-gradient(90deg, #6892d6 33.3%, transparent 33.3%);
# }
# #T_bda8f_row2_col2 {
#   background: linear-gradient(90deg, #6892d6 66.7%, transparent 66.7%);
#   text-decoration: underline;
# }
# #T_bda8f_row5_col0 {
#   background: linear-gradient(90deg, #6892d6 33.3%, transparent 33.3%);
#   text-decoration: underline;
# }
# </style>
# <table id="T_bda8f">
#   <caption>Table 3.1. Multiple runs</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bda8f_level0_col0" class="col_heading level0 col0" >Charge↑</th>
#       <th id="T_bda8f_level0_col1" class="col_heading level0 col1" >Uniqueness↑</th>
#       <th id="T_bda8f_level0_col2" class="col_heading level0 col2" >Rank↓</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bda8f_level0_row0" class="row_heading level0 row0" rowspan="3">model 1</th>
#       <th id="T_bda8f_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_bda8f_row0_col0" class="data row0 col0" >0.66±0.47</td>
#       <td id="T_bda8f_row0_col1" class="data row0 col1" >1.00±0.00</td>
#       <td id="T_bda8f_row0_col2" class="data row0 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_bda8f_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_bda8f_row1_col0" class="data row1 col0" >1.00±0.47</td>
#       <td id="T_bda8f_row1_col1" class="data row1 col1" >1.00±0.00</td>
#       <td id="T_bda8f_row1_col2" class="data row1 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_bda8f_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_bda8f_row2_col0" class="data row2 col0" >3.66±0.00</td>
#       <td id="T_bda8f_row2_col1" class="data row2 col1" >0.67±0.00</td>
#       <td id="T_bda8f_row2_col2" class="data row2 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_bda8f_level0_row3" class="row_heading level0 row3" rowspan="3">model 2</th>
#       <th id="T_bda8f_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_bda8f_row3_col0" class="data row3 col0" >0.66±0.00</td>
#       <td id="T_bda8f_row3_col1" class="data row3 col1" >1.00±0.00</td>
#       <td id="T_bda8f_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_bda8f_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_bda8f_row4_col0" class="data row4 col0" >0.66±0.00</td>
#       <td id="T_bda8f_row4_col1" class="data row4 col1" >1.00±0.00</td>
#       <td id="T_bda8f_row4_col2" class="data row4 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_bda8f_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_bda8f_row5_col0" class="data row5 col0" >1.66±0.00</td>
#       <td id="T_bda8f_row5_col1" class="data row5 col1" >1.00±0.00</td>
#       <td id="T_bda8f_row5_col2" class="data row5 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's extract the top two ranked entries.

# %%
sm.show(
    sm.top_k(df_combined, "Rank", 2),
    color="#6892d6",
    color_style="bar",
    caption="Table 3.2. Multiple runs - Best",
    n_decimals=[2, 2, 0],
)
# Out:
# <style type="text/css">
# #T_96111 th.col_heading {
#   text-align: center;
# }
# #T_96111 td {
#   border-right: 1px solid #ccc;
# }
# #T_96111 th.row_heading {
#   border-right: 1px solid #ccc;
# }
# #T_96111 tbody tr:nth-child(2) td {
#   border-top: 1px solid #ccc;
# }
# #T_96111  tbody tr:nth-child(2) th {
#   border-top: 1px solid #ccc;
# }
# #T_96111 caption {
#   caption-side: bottom;
#   margin-top: 0.75em;
# }
# #T_96111_row0_col0, #T_96111_row1_col1, #T_96111_row1_col2 {
#   background: linear-gradient(90deg, #6892d6 100.0%, transparent 100.0%);
#   font-weight: bold;
# }
# #T_96111_row0_col1, #T_96111_row0_col2, #T_96111_row1_col0 {
#   text-decoration: underline;
# }
# </style>
# <table id="T_96111">
#   <caption>Table 3.2. Multiple runs - Best</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96111_level0_col0" class="col_heading level0 col0" >Charge↑</th>
#       <th id="T_96111_level0_col1" class="col_heading level0 col1" >Uniqueness↑</th>
#       <th id="T_96111_level0_col2" class="col_heading level0 col2" >Rank↓</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96111_level0_row0" class="row_heading level0 row0" >model 1</th>
#       <th id="T_96111_level1_row0" class="row_heading level1 row0" >3</th>
#       <td id="T_96111_row0_col0" class="data row0 col0" >3.66±0.00</td>
#       <td id="T_96111_row0_col1" class="data row0 col1" >0.67±0.00</td>
#       <td id="T_96111_row0_col2" class="data row0 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_96111_level0_row1" class="row_heading level0 row1" >model 2</th>
#       <th id="T_96111_level1_row1" class="row_heading level1 row1" >3</th>
#       <td id="T_96111_row1_col0" class="data row1 col0" >1.66±0.00</td>
#       <td id="T_96111_row1_col1" class="data row1 col1" >1.00±0.00</td>
#       <td id="T_96111_row1_col2" class="data row1 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's visualize the sequences performance at each iteration.

# %%
sm.plot_line(df_combined, "Charge", color=["#ff4949ff", "#29a1c6ff"], linestyle=["--", "-"], marker=None)
